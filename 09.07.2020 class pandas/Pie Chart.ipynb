# %%
activities=["eat","play","sleep","work"]
hours=[3,2,9,10]

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(hours,labels=activities,colors=("r","g","b","y"),radius=2.0,
       autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1b7d3690e08>,
# ...
#  [Text(2.032534971524831, 0.8419035512031976, 'eat'),
#   Text(1.0999999851347562, 1.9052558969082178, 'play'),
#   Text(-1.7453773695393817, 1.3392751165835157, 'sleep'),
#   Text(0.5694018660654946, -2.125036826721159, 'work')],
#  [Text(1.1086554390135441, 0.4592201188381077, '12.50%'),
#   Text(0.5999999918916851, 1.039230489222664, '8.33%'),
#   Text(-0.9520240197487535, 0.7305136999546449, '37.50%'),
#   Text(0.3105828360357243, -1.1591109963933592, '41.67%')])
